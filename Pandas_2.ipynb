# %% [markdown]
# <a href="https://colab.research.google.com/github/sofia3108548001/Pandas/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import pandas as pd

encuesta = pd.DataFrame(
    {
        "Julia": ["me gusto", "Fue horrible"],
        "Pedro": ["Fue delicioso", "No estuvo tan mal"],
    },
    index=["Restaurante_1", "Restaurante 2"]
)

encuesta
# Out:
#                       Julia              Pedro
# Restaurante_1      me gusto      Fue delicioso
# Restaurante 2  Fue horrible  No estuvo tan mal

# %% [markdown]
# ## Cargar Archivos CSV en un dataframe

# %%
#Leer archivos csv
miCSV= pd.read_csv("DATOS.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiantes_1   Estudiantes_2   Estudiantes_3
# 0             32              45              10
# 1             40              25              39
# 2             45              42              47

# %%
miTitanic=pd.read_csv("archive.zip")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miTitanicFiltrado= miTitanic[miTitanic["Survived"]==0]
miTitanicFiltrado.count()
# Out:
# PassengerId    265
# Survived       265
# dtype: int64

# %%
#Sumar todos los sobrevivientes del titanic

# %%
miTitanicFiltrado= miTitanic[miTitanic["Survived"]> 0]
miTitanicFiltrado.count()
# Out:
# PassengerId    153
# Survived       153
# dtype: int64

# %%
miTitanicFiltrado = miTitanic[miTitanic["Survived"] == 1]
miTitanicFiltrado.sum()
# Out:
# PassengerId    167158
# Survived          153
# dtype: int64

# %%
MiNetflix=pd.read_csv("Netflix.csv.zip")
MiNetflix.shape
MiNetflix.head()
# Out:
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %% [markdown]
# ## .describe
# Nos muestra los datos estadisticos

# %%
MiNetflix.describe()
# Out:
#        Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# count    1.700000e+01            1.700000e+01            1.700000e+01
# mean     6.742788e+09            3.068941e+09            2.075164e+09
# std      1.197879e+09            4.209004e+08            4.594011e+08
# min      4.520992e+09            2.256851e+09            1.233379e+09
# 25%      5.767691e+09            2.702776e+09            1.723474e+09
# 50%      7.163282e+09            3.170972e+09            2.343674e+09
# 75%      7.852053e+09            3.350424e+09            2.432239e+09
# max      8.161503e+09            3.608645e+09            2.561831e+09
#
#        LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# count            1.700000e+01            1.700000e+01  1.700000e+01
# mean             8.629001e+08            6.830686e+08  7.207747e+07
# std              1.349618e+08            2.204141e+08  3.129072e+06
# ...

# %% [markdown]
# #Selecccinar filas especificas
# Filtrar filas

# %%
misPeliculas=pd.read_csv("IMDb.csv")
